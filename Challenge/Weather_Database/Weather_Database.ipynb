# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

#coordinates = list(lat_lngs)
#for coordinate in coordinates:
    #print(coordinate[0], coordinate[1])

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
import time

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Conver the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port hueneme
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | juneau
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | lata
# Processing Record 6 of Set 1 | urdoma
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | russell
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | balkanabat
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | ewo
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | tucano
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 1 | toora-khem
# Processing Record 21 of Set 1 | kavaratti
# Processing Record 22 of Set 1 | kobryn
# Processing Record 23 of Set 1 | dankov
# Processing Record 24 of Set 1 | ostrovnoy
# Processing Record 25 of Set 1 | harwich
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | kholm
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | aykhal
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | naberera
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 | san andres
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | owando
# Processing Record 40 of Set 1 | lodja
# Processing Record 41 of Set 1 | binga
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | miri
# Processing Record 45 of Set 1 | sur
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | aguimes
# Processing Record 48 of Set 1 | turiacu
# Processing Record 49 of Set 1 | cap malheureux
# Processing Record 50 of Set 1 | sterling
# Processing Record 1 of Set 2 | nanakuli
# Processing Record 2 of Set 2 | atbasar
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | svetlogorsk
# Processing Record 5 of Set 2 | port-gentil
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | batticaloa
# Processing Record 9 of Set 2 | san patricio
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | nelson bay
# Processing Record 14 of Set 2 | coihaique
# Processing Record 15 of Set 2 | taoudenni
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | kichera
# Processing Record 19 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | kedrovyy
# Processing Record 23 of Set 2 | mayskiy
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | vila
# Processing Record 26 of Set 2 | northam
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | port lincoln
# Processing Record 30 of Set 2 | nhulunbuy
# Processing Record 31 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 2 | kosh-agach
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | mount gambier
# Processing Record 36 of Set 2 | broome
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | port hedland
# Processing Record 39 of Set 2 | balsas
# Processing Record 40 of Set 2 | ayan
# Processing Record 41 of Set 2 | touros
# Processing Record 42 of Set 2 | sohag
# Processing Record 43 of Set 2 | shediac
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | monrovia
# Processing Record 46 of Set 2 | dingle
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | ahipara
# Processing Record 49 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 2 | astipalaia
# City not found. Skipping...
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | amga
# Processing Record 3 of Set 3 | dodge city
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | saskylakh
# Processing Record 7 of Set 3 | banepa
# Processing Record 8 of Set 3 | akim swedru
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | dudinka
# Processing Record 12 of Set 3 | vanavara
# Processing Record 13 of Set 3 | texiguat
# Processing Record 14 of Set 3 | dzhebariki-khaya
# Processing Record 15 of Set 3 | westport
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | minuri
# Processing Record 19 of Set 3 | sola
# Processing Record 20 of Set 3 | pokrovsk
# Processing Record 21 of Set 3 | ukiah
# Processing Record 22 of Set 3 | dali
# Processing Record 23 of Set 3 | concarneau
# Processing Record 24 of Set 3 | namibe
# Processing Record 25 of Set 3 | waipawa
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | baykit
# Processing Record 28 of Set 3 | geraldton
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | cayenne
# Processing Record 31 of Set 3 | shakawe
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | ikwiriri
# Processing Record 34 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | khrustalnyy
# City not found. Skipping...
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | sao filipe
# Processing Record 39 of Set 3 | hailey
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | strezhevoy
# Processing Record 42 of Set 3 | pauini
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | quzhou
# Processing Record 45 of Set 3 | sandpoint
# Processing Record 46 of Set 3 | tarakan
# Processing Record 47 of Set 3 | marsabit
# Processing Record 48 of Set 3 | prieska
# Processing Record 49 of Set 3 | santa isabel do rio negro
# Processing Record 50 of Set 3 | ancud
# Processing Record 1 of Set 4 | necochea
# Processing Record 2 of Set 4 | jaca
# Processing Record 3 of Set 4 | price
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | kulhudhuffushi
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | samarai
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 4 | esperance
# Processing Record 16 of Set 4 | chumikan
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | mitsamiouli
# Processing Record 19 of Set 4 | mapiripan
# Processing Record 20 of Set 4 | katima mulilo
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | puerto narino
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | east chicago
# Processing Record 25 of Set 4 | jhanjharpur
# Processing Record 26 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 4 | ugoofaaru
# Processing Record 28 of Set 4 | nizwa
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | arlit
# Processing Record 32 of Set 4 | nagato
# Processing Record 33 of Set 4 | biltine
# Processing Record 34 of Set 4 | pokhara
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | alta floresta
# Processing Record 37 of Set 4 | camopi
# Processing Record 38 of Set 4 | flinders
# Processing Record 39 of Set 4 | kudahuvadhoo
# Processing Record 40 of Set 4 | coquimbo
# Processing Record 41 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 4 | hasaki
# Processing Record 43 of Set 4 | rawatsar
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | shingu
# Processing Record 46 of Set 4 | kathmandu
# Processing Record 47 of Set 4 | bandarbeyla
# Processing Record 48 of Set 4 | monterey
# Processing Record 49 of Set 4 | lagoa
# Processing Record 50 of Set 4 | dongli
# Processing Record 1 of Set 5 | bogoslovka
# Processing Record 2 of Set 5 | alofi
# Processing Record 3 of Set 5 | provideniya
# Processing Record 4 of Set 5 | sechura
# Processing Record 5 of Set 5 | walvis bay
# Processing Record 6 of Set 5 | okato
# Processing Record 7 of Set 5 | kalmunai
# Processing Record 8 of Set 5 | beroroha
# Processing Record 9 of Set 5 | asnaes
# Processing Record 10 of Set 5 | paamiut
# Processing Record 11 of Set 5 | ilulissat
# Processing Record 12 of Set 5 | erenhot
# Processing Record 13 of Set 5 | deputatskiy
# Processing Record 14 of Set 5 | oranjemund
# Processing Record 15 of Set 5 | palhi
# Processing Record 16 of Set 5 | buraydah
# Processing Record 17 of Set 5 | khromtau
# Processing Record 18 of Set 5 | opuwo
# Processing Record 19 of Set 5 | kirakira
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | port hardy
# Processing Record 22 of Set 5 | general pico
# Processing Record 23 of Set 5 | upernavik
# Processing Record 24 of Set 5 | ternate
# Processing Record 25 of Set 5 | half moon bay
# Processing Record 26 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 5 | popondetta
# Processing Record 28 of Set 5 | puerto ayora
# Processing Record 29 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | okhotsk
# Processing Record 32 of Set 5 | klaksvik
# Processing Record 33 of Set 5 | lithakia
# Processing Record 34 of Set 5 | bambous virieux
# Processing Record 35 of Set 5 | eten
# Processing Record 36 of Set 5 | batagay
# Processing Record 37 of Set 5 | pedernales
# Processing Record 38 of Set 5 | tingi
# Processing Record 39 of Set 5 | xinqing
# Processing Record 40 of Set 5 | ridgecrest
# Processing Record 41 of Set 5 | shenzhen
# Processing Record 42 of Set 5 | srednekolymsk
# Processing Record 43 of Set 5 | cao bang
# Processing Record 44 of Set 5 | haapu
# City not found. Skipping...
# Processing Record 45 of Set 5 | avera
# Processing Record 46 of Set 5 | beloha
# Processing Record 47 of Set 5 | gushikawa
# Processing Record 48 of Set 5 | najran
# Processing Record 49 of Set 5 | hakui
# Processing Record 50 of Set 5 | lagunillas
# Processing Record 1 of Set 6 | severnyy
# Processing Record 2 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 6 | port alfred
# Processing Record 4 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 5 of Set 6 | clyde river
# Processing Record 6 of Set 6 | king city
# Processing Record 7 of Set 6 | kieta
# Processing Record 8 of Set 6 | padang
# Processing Record 9 of Set 6 | kruisfontein
# Processing Record 10 of Set 6 | fortuna
# Processing Record 11 of Set 6 | tual
# Processing Record 12 of Set 6 | vao
# Processing Record 13 of Set 6 | saint george
# Processing Record 14 of Set 6 | salinas
# Processing Record 15 of Set 6 | petukhovo
# Processing Record 16 of Set 6 | constantine
# Processing Record 17 of Set 6 | ponta delgada
# Processing Record 18 of Set 6 | sakakah
# Processing Record 19 of Set 6 | bara
# Processing Record 20 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 6 | mogadishu
# Processing Record 22 of Set 6 | kusk
# City not found. Skipping...
# Processing Record 23 of Set 6 | constitucion
# Processing Record 24 of Set 6 | fukue
# Processing Record 25 of Set 6 | namatanai
# Processing Record 26 of Set 6 | yerbogachen
# Processing Record 27 of Set 6 | kamsack
# Processing Record 28 of Set 6 | buin
# Processing Record 29 of Set 6 | banda aceh
# Processing Record 30 of Set 6 | antofagasta
# Processing Record 31 of Set 6 | guerrero negro
# Processing Record 32 of Set 6 | wasilla
# Processing Record 33 of Set 6 | trapani
# Processing Record 34 of Set 6 | bambanglipuro
# Processing Record 35 of Set 6 | sorland
# Processing Record 36 of Set 6 | asau
# Processing Record 37 of Set 6 | roma
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | killarney
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | dolinsk
# Processing Record 42 of Set 6 | hami
# Processing Record 43 of Set 6 | nogales
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | ballina
# Processing Record 46 of Set 6 | kisangani
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | rocha
# Processing Record 49 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 50 of Set 6 | pierre
# Processing Record 1 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 2 of Set 7 | warri
# Processing Record 3 of Set 7 | tucuman
# Processing Record 4 of Set 7 | tortoli
# Processing Record 5 of Set 7 | college
# Processing Record 6 of Set 7 | komsomolskiy
# Processing Record 7 of Set 7 | miandrivazo
# Processing Record 8 of Set 7 | monte cristi
# City not found. Skipping...
# Processing Record 9 of Set 7 | ifakara
# Processing Record 10 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 7 | miranda
# Processing Record 12 of Set 7 | yueyang
# Processing Record 13 of Set 7 | syracuse
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | tocopilla
# Processing Record 16 of Set 7 | rawson
# Processing Record 17 of Set 7 | nezlobnaya
# Processing Record 18 of Set 7 | beira
# Processing Record 19 of Set 7 | kuala krai
# City not found. Skipping...
# Processing Record 20 of Set 7 | denia
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | silver city
# Processing Record 23 of Set 7 | kampot
# Processing Record 24 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | chirongui
# Processing Record 27 of Set 7 | san pedro de macoris
# Processing Record 28 of Set 7 | concordia
# Processing Record 29 of Set 7 | nalut
# Processing Record 30 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 7 | saint-joseph
# Processing Record 32 of Set 7 | ust-koksa
# Processing Record 33 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 34 of Set 7 | manati
# Processing Record 35 of Set 7 | southbury
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 7 | huarmey
# Processing Record 39 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 7 | sinnamary
# Processing Record 41 of Set 7 | tezu
# Processing Record 42 of Set 7 | olutanga
# Processing Record 43 of Set 7 | pisco
# Processing Record 44 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 7 | grand-santi
# Processing Record 46 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 7 | nusaybin
# Processing Record 48 of Set 7 | valdivia
# Processing Record 49 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 50 of Set 7 | carnarvon
# Processing Record 1 of Set 8 | pouebo
# Processing Record 2 of Set 8 | nyagan
# Processing Record 3 of Set 8 | muravlenko
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | doha
# Processing Record 6 of Set 8 | coria
# Processing Record 7 of Set 8 | kaohsiung
# Processing Record 8 of Set 8 | udomlya
# Processing Record 9 of Set 8 | maneadero
# Processing Record 10 of Set 8 | roros
# Processing Record 11 of Set 8 | strai
# Processing Record 12 of Set 8 | piacabucu
# Processing Record 13 of Set 8 | taltal
# Processing Record 14 of Set 8 | christchurch
# Processing Record 15 of Set 8 | thinadhoo
# Processing Record 16 of Set 8 | inirida
# Processing Record 17 of Set 8 | kapoeta
# Processing Record 18 of Set 8 | saint-pierre
# Processing Record 19 of Set 8 | peterongan
# Processing Record 20 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 8 | lebane
# Processing Record 22 of Set 8 | homer
# Processing Record 23 of Set 8 | champerico
# Processing Record 24 of Set 8 | gannan
# Processing Record 25 of Set 8 | banyo
# Processing Record 26 of Set 8 | liku
# Processing Record 27 of Set 8 | katherine
# Processing Record 28 of Set 8 | rajauri
# Processing Record 29 of Set 8 | inhambane
# Processing Record 30 of Set 8 | sinj
# Processing Record 31 of Set 8 | brae
# Processing Record 32 of Set 8 | sucua
# Processing Record 33 of Set 8 | tuatapere
# Processing Record 34 of Set 8 | jurm
# Processing Record 35 of Set 8 | belaya gora
# Processing Record 36 of Set 8 | novikovo
# Processing Record 37 of Set 8 | eureka
# Processing Record 38 of Set 8 | zhanaozen
# Processing Record 39 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 40 of Set 8 | ibra
# Processing Record 41 of Set 8 | souillac
# Processing Record 42 of Set 8 | nadadores
# Processing Record 43 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 8 | tutoia
# Processing Record 45 of Set 8 | makakilo city
# Processing Record 46 of Set 8 | sandwick
# Processing Record 47 of Set 8 | victor harbor
# Processing Record 48 of Set 8 | giyon
# Processing Record 49 of Set 8 | tabuk
# Processing Record 50 of Set 8 | winneba
# Processing Record 1 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 2 of Set 9 | rio gallegos
# Processing Record 3 of Set 9 | bontang
# Processing Record 4 of Set 9 | altay
# Processing Record 5 of Set 9 | nador
# Processing Record 6 of Set 9 | mizdah
# Processing Record 7 of Set 9 | dawei
# Processing Record 8 of Set 9 | nishihara
# Processing Record 9 of Set 9 | kodinsk
# Processing Record 10 of Set 9 | escanaba
# Processing Record 11 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 9 | plainview
# Processing Record 13 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 9 | tefe
# Processing Record 15 of Set 9 | ust-tsilma
# Processing Record 16 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 9 | tautira
# Processing Record 18 of Set 9 | pevek
# Processing Record 19 of Set 9 | itaituba
# Processing Record 20 of Set 9 | chiapilla
# Processing Record 21 of Set 9 | porto novo
# Processing Record 22 of Set 9 | ambon
# Processing Record 23 of Set 9 | palmer
# Processing Record 24 of Set 9 | kawalu
# Processing Record 25 of Set 9 | conde
# Processing Record 26 of Set 9 | narsaq
# Processing Record 27 of Set 9 | lipin bor
# Processing Record 28 of Set 9 | ferrol
# Processing Record 29 of Set 9 | sarkand
# Processing Record 30 of Set 9 | waimes
# Processing Record 31 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 9 | yeppoon
# Processing Record 33 of Set 9 | sao joao da barra
# Processing Record 34 of Set 9 | cabedelo
# Processing Record 35 of Set 9 | gat
# Processing Record 36 of Set 9 | koulikoro
# Processing Record 37 of Set 9 | bereda
# Processing Record 38 of Set 9 | karonga
# Processing Record 39 of Set 9 | lavrentiya
# Processing Record 40 of Set 9 | osoyoos
# Processing Record 41 of Set 9 | mehamn
# Processing Record 42 of Set 9 | hazorasp
# Processing Record 43 of Set 9 | la ronge
# Processing Record 44 of Set 9 | zhigansk
# Processing Record 45 of Set 9 | zarubino
# Processing Record 46 of Set 9 | ojinaga
# Processing Record 47 of Set 9 | huanren
# Processing Record 48 of Set 9 | egvekinot
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | kathu
# Processing Record 1 of Set 10 | hualmay
# Processing Record 2 of Set 10 | nome
# Processing Record 3 of Set 10 | sokoni
# Processing Record 4 of Set 10 | codrington
# Processing Record 5 of Set 10 | anloga
# Processing Record 6 of Set 10 | zyryanovsk
# Processing Record 7 of Set 10 | umm lajj
# Processing Record 8 of Set 10 | along
# Processing Record 9 of Set 10 | alugan
# Processing Record 10 of Set 10 | sao francisco
# Processing Record 11 of Set 10 | trelew
# Processing Record 12 of Set 10 | ndola
# Processing Record 13 of Set 10 | dunedin
# Processing Record 14 of Set 10 | mandera
# Processing Record 15 of Set 10 | kibaya
# Processing Record 16 of Set 10 | leninskoye
# Processing Record 17 of Set 10 | chernyshevskiy
# Processing Record 18 of Set 10 | mayo
# Processing Record 19 of Set 10 | the valley
# Processing Record 20 of Set 10 | atar
# Processing Record 21 of Set 10 | othonoi
# City not found. Skipping...
# Processing Record 22 of Set 10 | gotsu
# Processing Record 23 of Set 10 | motygino
# Processing Record 24 of Set 10 | maldonado
# Processing Record 25 of Set 10 | aklavik
# Processing Record 26 of Set 10 | svetlyy
# Processing Record 27 of Set 10 | divnogorsk
# Processing Record 28 of Set 10 | honiara
# Processing Record 29 of Set 10 | morondava
# Processing Record 30 of Set 10 | muros
# Processing Record 31 of Set 10 | cabo san lucas
# Processing Record 32 of Set 10 | hovd
# Processing Record 33 of Set 10 | bonavista
# Processing Record 34 of Set 10 | albanel
# Processing Record 35 of Set 10 | teya
# Processing Record 36 of Set 10 | belogorsk
# Processing Record 37 of Set 10 | bulgan
# Processing Record 38 of Set 10 | praia da vitoria
# Processing Record 39 of Set 10 | luebo
# Processing Record 40 of Set 10 | ixtapa
# Processing Record 41 of Set 10 | cherskiy
# Processing Record 42 of Set 10 | berlevag
# Processing Record 43 of Set 10 | ospitaletto
# Processing Record 44 of Set 10 | morehead
# Processing Record 45 of Set 10 | razole
# Processing Record 46 of Set 10 | brigantine
# Processing Record 47 of Set 10 | sayyan
# Processing Record 48 of Set 10 | peterhead
# Processing Record 49 of Set 10 | mareeba
# Processing Record 50 of Set 10 | uyo
# Processing Record 1 of Set 11 | puqi
# Processing Record 2 of Set 11 | bagdarin
# Processing Record 3 of Set 11 | ambilobe
# Processing Record 4 of Set 11 | nexo
# Processing Record 5 of Set 11 | san jose
# Processing Record 6 of Set 11 | ola
# Processing Record 7 of Set 11 | mackay
# Processing Record 8 of Set 11 | nara
# Processing Record 9 of Set 11 | umarkot
# Processing Record 10 of Set 11 | nizhnevartovsk
# Processing Record 11 of Set 11 | lichinga
# Processing Record 12 of Set 11 | kupang
# Processing Record 13 of Set 11 | mbandaka
# Processing Record 14 of Set 11 | yuncheng
# Processing Record 15 of Set 11 | naze
# Processing Record 16 of Set 11 | flin flon
# Processing Record 17 of Set 11 | sao felix do xingu
# Processing Record 18 of Set 11 | maragogi
# Processing Record 19 of Set 11 | takhtamygda
# Processing Record 20 of Set 11 | ulaangom
# Processing Record 21 of Set 11 | marzuq
# Processing Record 22 of Set 11 | boden
# Processing Record 23 of Set 11 | kantilo
# Processing Record 24 of Set 11 | vigrestad
# Processing Record 25 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 11 | cidreira
# Processing Record 28 of Set 11 | bay roberts
# Processing Record 29 of Set 11 | gua musang
# Processing Record 30 of Set 11 | cordoba
# Processing Record 31 of Set 11 | san luis
# Processing Record 32 of Set 11 | karratha
# Processing Record 33 of Set 11 | seoul
# Processing Record 34 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 11 | meulaboh
# Processing Record 36 of Set 11 | uvat
# Processing Record 37 of Set 11 | abadan
# Processing Record 38 of Set 11 | mazagao
# Processing Record 39 of Set 11 | melito di porto salvo
# Processing Record 40 of Set 11 | mountain view
# Processing Record 41 of Set 11 | san buenaventura
# Processing Record 42 of Set 11 | santa rosa
# Processing Record 43 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 44 of Set 11 | amahai
# Processing Record 45 of Set 11 | honningsvag
# Processing Record 46 of Set 11 | alamogordo
# Processing Record 47 of Set 11 | dalvik
# Processing Record 48 of Set 11 | turukhansk
# Processing Record 49 of Set 11 | sumter
# Processing Record 50 of Set 11 | ye
# City not found. Skipping...
# Processing Record 1 of Set 12 | caravelas
# Processing Record 2 of Set 12 | fojnica
# Processing Record 3 of Set 12 | mapiri
# Processing Record 4 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 5 of Set 12 | arman
# Processing Record 6 of Set 12 | houma
# Processing Record 7 of Set 12 | kahului
# Processing Record 8 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 12 | acapulco
# Processing Record 10 of Set 12 | pestravka
# Processing Record 11 of Set 12 | san juan
# Processing Record 12 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 12 | tazmalt
# Processing Record 14 of Set 12 | anori
# Processing Record 15 of Set 12 | bay city
# Processing Record 16 of Set 12 | johi
# Processing Record 17 of Set 12 | perigueux
# Processing Record 18 of Set 12 | leningradskiy
# Processing Record 19 of Set 12 | ulladulla
# Processing Record 20 of Set 12 | taganak
# Processing Record 21 of Set 12 | ust-ishim
# Processing Record 22 of Set 12 | ketchikan
# Processing Record 23 of Set 12 | fengzhen
# Processing Record 24 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 12 | xinxiang
# Processing Record 26 of Set 12 | araouane
# Processing Record 27 of Set 12 | kyshtovka
# Processing Record 28 of Set 12 | sri aman
# Processing Record 29 of Set 12 | pacific grove
# Processing Record 30 of Set 12 | bubaque
# Processing Record 31 of Set 12 | rujiena
# Processing Record 32 of Set 12 | aviles
# Processing Record 33 of Set 12 | great yarmouth
# Processing Record 34 of Set 12 | superior
# Processing Record 35 of Set 12 | martinopolis
# Processing Record 36 of Set 12 | adrar
# Processing Record 37 of Set 12 | gimli
# Processing Record 38 of Set 12 | cuauhtemoc
# Processing Record 39 of Set 12 | ayia galini
# Processing Record 40 of Set 12 | ankazoabo
# Processing Record 41 of Set 12 | mednogorsk
# Processing Record 42 of Set 12 | pingliang
# Processing Record 43 of Set 12 | portland
# Processing Record 44 of Set 12 | labuan
# Processing Record 45 of Set 12 | santo tomas
# Processing Record 46 of Set 12 | okahandja
# Processing Record 47 of Set 12 | dajabon
# Processing Record 48 of Set 12 | loukhi
# Processing Record 49 of Set 12 | rio grande
# Processing Record 50 of Set 12 | iqaluit
# Processing Record 1 of Set 13 | beisfjord
# Processing Record 2 of Set 13 | cascais
# Processing Record 3 of Set 13 | saint-augustin
# Processing Record 4 of Set 13 | buala
# Processing Record 5 of Set 13 | wattegama
# Processing Record 6 of Set 13 | balkhash
# Processing Record 7 of Set 13 | tinaquillo
# Processing Record 8 of Set 13 | filadelfia
# Processing Record 9 of Set 13 | payo
# Processing Record 10 of Set 13 | alyangula
# Processing Record 11 of Set 13 | dong xoai
# Processing Record 12 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 14 of Set 13 | port augusta
# Processing Record 15 of Set 13 | selikhino
# Processing Record 16 of Set 13 | zinder
# Processing Record 17 of Set 13 | koumra
# Processing Record 18 of Set 13 | canaries
# Processing Record 19 of Set 13 | wageningen
# Processing Record 20 of Set 13 | torbat-e jam
# Processing Record 21 of Set 13 | maningrida
# Processing Record 22 of Set 13 | vila velha
# Processing Record 23 of Set 13 | husavik
# Processing Record 24 of Set 13 | shadegan
# Processing Record 25 of Set 13 | yuxia
# Processing Record 26 of Set 13 | sheltozero
# Processing Record 27 of Set 13 | marystown
# Processing Record 28 of Set 13 | texarkana
# Processing Record 29 of Set 13 | urumqi
# Processing Record 30 of Set 13 | wanning
# Processing Record 31 of Set 13 | gay
# Processing Record 32 of Set 13 | nyimba
# Processing Record 33 of Set 13 | sibolga
# Processing Record 34 of Set 13 | ndouci
# City not found. Skipping...
# Processing Record 35 of Set 13 | olafsvik
# Processing Record 36 of Set 13 | teguise
# Processing Record 37 of Set 13 | rio verde de mato grosso
# Processing Record 38 of Set 13 | kuala terengganu
# Processing Record 39 of Set 13 | rosetta
# Processing Record 40 of Set 13 | guider
# Processing Record 41 of Set 13 | pokosnoye
# Processing Record 42 of Set 13 | irtyshskiy
# Processing Record 43 of Set 13 | kadoma
# Processing Record 44 of Set 13 | arroyo
# Processing Record 45 of Set 13 | salinopolis
# Processing Record 46 of Set 13 | kaura namoda
# Processing Record 47 of Set 13 | mount isa
# Processing Record 48 of Set 13 | jaicos
# Processing Record 49 of Set 13 | kautokeino
# Processing Record 50 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 14 | rantepao
# Processing Record 2 of Set 14 | devon
# Processing Record 3 of Set 14 | kapit
# Processing Record 4 of Set 14 | gamba
# Processing Record 5 of Set 14 | khani
# Processing Record 6 of Set 14 | kula
# Processing Record 7 of Set 14 | bethanien
# Processing Record 8 of Set 14 | revelstoke
# Processing Record 9 of Set 14 | tallahassee
# Processing Record 10 of Set 14 | bowen
# Processing Record 11 of Set 14 | winnemucca
# Processing Record 12 of Set 14 | haines junction
# Processing Record 13 of Set 14 | noumea
# Processing Record 14 of Set 14 | makokou
# Processing Record 15 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 16 of Set 14 | vaitape
# Processing Record 17 of Set 14 | dingli
# Processing Record 18 of Set 14 | maniitsoq
# Processing Record 19 of Set 14 | tessalit
# Processing Record 20 of Set 14 | balikpapan
# Processing Record 21 of Set 14 | kuito
# Processing Record 22 of Set 14 | derzhavinsk
# Processing Record 23 of Set 14 | murgab
# Processing Record 24 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 14 | santa isabel
# Processing Record 26 of Set 14 | beloostrov
# Processing Record 27 of Set 14 | sao luiz gonzaga
# Processing Record 28 of Set 14 | saldanha
# Processing Record 29 of Set 14 | viransehir
# Processing Record 30 of Set 14 | luanda
# Processing Record 31 of Set 14 | sangar
# Processing Record 32 of Set 14 | chiredzi
# Processing Record 33 of Set 14 | requena
# Processing Record 34 of Set 14 | shache
# Processing Record 35 of Set 14 | borovskoy
# Processing Record 36 of Set 14 | flagstaff
# Processing Record 37 of Set 14 | fagersta
# Processing Record 38 of Set 14 | omsukchan
# Processing Record 39 of Set 14 | malanje
# Processing Record 40 of Set 14 | aktau
# Processing Record 41 of Set 14 | margate
# Processing Record 42 of Set 14 | jiuquan
# Processing Record 43 of Set 14 | talnakh
# Processing Record 44 of Set 14 | vestmanna
# Processing Record 45 of Set 14 | camacha
# Processing Record 46 of Set 14 | tura
# Processing Record 47 of Set 14 | bam
# Processing Record 48 of Set 14 | giyani
# Processing Record 49 of Set 14 | taraz
# Processing Record 50 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 15 | basoko
# Processing Record 2 of Set 15 | bathsheba
# Processing Record 3 of Set 15 | tepango
# Processing Record 4 of Set 15 | manoel urbano
# Processing Record 5 of Set 15 | kirksville
# Processing Record 6 of Set 15 | zalesovo
# Processing Record 7 of Set 15 | magetan
# City not found. Skipping...
# Processing Record 8 of Set 15 | parsabad
# Processing Record 9 of Set 15 | tombouctou
# Processing Record 10 of Set 15 | sambava
# Processing Record 11 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 12 of Set 15 | dombasle-sur-meurthe
# Processing Record 13 of Set 15 | beringovskiy
# Processing Record 14 of Set 15 | mamallapuram
# Processing Record 15 of Set 15 | mbacke
# City not found. Skipping...
# Processing Record 16 of Set 15 | kizukuri
# Processing Record 17 of Set 15 | tsurib
# Processing Record 18 of Set 15 | bemidji
# Processing Record 19 of Set 15 | khvoynaya
# Processing Record 20 of Set 15 | vorukh
# Processing Record 21 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 15 | liverpool
# Processing Record 23 of Set 15 | upata
# Processing Record 24 of Set 15 | onega
# Processing Record 25 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 15 | witrivier
# City not found. Skipping...
# Processing Record 27 of Set 15 | tabas
# Processing Record 28 of Set 15 | shahr-e babak
# Processing Record 29 of Set 15 | santa maria
# Processing Record 30 of Set 15 | tadine
# Processing Record 31 of Set 15 | elat
# Processing Record 32 of Set 15 | darhan
# Processing Record 33 of Set 15 | burnie
# Processing Record 34 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 15 | ransang
# Processing Record 36 of Set 15 | belmonte
# Processing Record 37 of Set 15 | nieves
# Processing Record 38 of Set 15 | welkom
# Processing Record 39 of Set 15 | mitchell
# Processing Record 40 of Set 15 | leh
# Processing Record 41 of Set 15 | solnechnyy
# Processing Record 42 of Set 15 | storforshei
# Processing Record 43 of Set 15 | kim
# Processing Record 44 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 15 | gilazi
# City not found. Skipping...
# Processing Record 46 of Set 15 | agadez
# Processing Record 47 of Set 15 | yanam
# Processing Record 48 of Set 15 | pizarro
# Processing Record 49 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 50 of Set 15 | gaoual
# Processing Record 1 of Set 16 | san joaquin
# Processing Record 2 of Set 16 | pula
# Processing Record 3 of Set 16 | rodrigues alves
# Processing Record 4 of Set 16 | pasni
# Processing Record 5 of Set 16 | vostok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Hueneme  34.1478 -119.1951     66.79        68          75
# 1     Nikolskoye  59.7035   30.7861     24.69        90          98
# 2         Juneau  58.3019 -134.4197     19.40       100          20
# 3         Albany  42.6001  -73.9662     51.58        85         100
# 4           Lata  40.1629   -8.3327     51.08        93         100
# 5         Urdoma  61.7533   48.5442     19.51        97          98
# 6        Ushuaia -54.8000  -68.3000     51.42        57          40
# 7        Russell  32.3502  -85.1999     70.88        55           0
# 8      Busselton -33.6500  115.3333     62.35        79          99
# 9  Mar Del Plata -38.0023  -57.5575     65.08        97         100
#
#    Wind Speed Country Current Description                 Date
# 0       12.66      US       broken clouds  2022-11-30 22:29:56
# 1        3.76      RU     overcast clouds  2022-11-30 22:29:56
# 2        6.91      US          few clouds  2022-11-30 22:29:56
# 3        3.00      US     overcast clouds  2022-11-30 22:26:00
# 4        4.97      PT     overcast clouds  2022-11-30 22:29:57
# 5        3.33      RU          light snow  2022-11-30 22:29:57
# 6       23.02      AR    scattered clouds  2022-11-30 22:26:07
# 7       14.97      US           clear sky  2022-11-30 22:29:58
# 8       10.47      AU     overcast clouds  2022-11-30 22:21:19
# 9       15.01      AR                mist  2022-11-30 22:26:04

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                    "Humidity", "Cloudiness", "Wind Speed", 
                    "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Hueneme      US  34.1478 -119.1951     66.79        68          75
# 1    Nikolskoye      RU  59.7035   30.7861     24.69        90          98
# 2        Juneau      US  58.3019 -134.4197     19.40       100          20
# 3        Albany      US  42.6001  -73.9662     51.58        85         100
# 4          Lata      PT  40.1629   -8.3327     51.08        93         100
#
#    Wind Speed Current Description
# 0       12.66       broken clouds
# 1        3.76     overcast clouds
# 2        6.91          few clouds
# 3        3.00     overcast clouds
# 4        4.97     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
